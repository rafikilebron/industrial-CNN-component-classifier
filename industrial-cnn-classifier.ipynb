# %% [markdown]
# # 1. SETUP

# %% [markdown]
# These sections correspond to the initial setup for this lab.

# %% [markdown]
# ## 1.1 Imports

# %% [markdown]
# The following Python libraries are necessary to run this notebook:

# %%
# Deep Learning
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader

# File management
import os
# Avoid conflicts with PyTorch and Matplotlib
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# Custom modules
from src.dataset import DatasetCreator
from src.models import ResNet18
from src.trainer import Trainer

# Data processing and visualization
import random
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## 1.2 Auxiliary functions

# %% [markdown]
# These functions are used to automate some repetitive process during model training and visualize model performance.

# %% [markdown]
# - Function used to plot the **validation accuracy** and **loss/cost** during the CNN training phase.

# %%
def plot_results(loss, accuracy, save=False, plot_name='train_results'):
    fig, ax1 = plt.subplots()

    # Plot loss
    color = 'tab:red'
    ax1.plot(loss, color=color)
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('LOSS', color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    # Copy axis
    ax2 = ax1.twinx()

    # Plot accuracy
    color = 'tab:blue'
    ax2.plot(accuracy, color=color)
    ax2.set_ylabel('ACCURACY', color=color)
    ax2.tick_params(axis='y', labelcolor=color)

    # Adjust layout
    fig.tight_layout()

    if save:
        plt.savefig(os.path.join(src_plots, plot_name), dpi=300, bbox_inches="tight")

    plt.show()

# %% [markdown]
# - Function used to plot a sample image using **Pillow**.

# %%
def _imshow(path, title=''):
    image = Image.open(path).convert('RGB')
    plt.imshow(image)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %% [markdown]
# - Function used to save a trained model as a `.pt` file.

# %%
def save_model_as_pt(model, name):
    if not name.endswith('.pt'):
        raise ValueError(f"Incorrect extension in '{name}'. Must be '.pt' file.")

    out_path = os.path.join(src_models, name)
    torch.save(model.state_dict(), out_path)

    print("Model saved at", src_models)

# %% [markdown]
# - Function used to load a **model.pt**

# %%
def load_model(model, pt_file_dir, device="cpu"):
    if not pt_file_dir.endswith('.pt'):
        raise ValueError(f"Incorrect file extension. Must be '.pt' file.")

    if not os.path.exists(pt_file_dir):
        raise FileNotFoundError(f"{pt_file_dir} does not exists.")

    # Load trained weights
    model.load_state_dict(torch.load(pt_file_dir, map_location=torch.device(device)))
    print(f"Successfully loaded from {pt_file_dir}")

    return model

# %% [markdown]
# - Function used to transform **Pillow** image to tensor.

# %%
def transform_image(img_path, transform):
    # Read image
    image = Image.open(img_path).convert('RGB')
    # Transform image
    tensor = transform(image).unsqueeze(0)
    return tensor

# %% [markdown]
# ## 1.3 Set Directories

# %% [markdown]
# Some directories must be declared to store files and create datasets from images' folders.

# %%
# Source directories
src_models  = "./outputs/models"
src_plots   = "./outputs/plots"

# Datasets' directories
housing_dataset_input_dir   = "./datasets/housing-classification/train_images"
housing_dataset_output_dir  = "./datasets/housing-classification"
housing_test_images_dir     = "./datasets/housing-classification/test_images"

# %% [markdown]
# # 2. CNN

# %% [markdown]
# ## 2.1 Create Dataset (Train/Validation)

# %% [markdown]
# ### 2.1.1 Define Transforms

# %% [markdown]
# The dataset of this application is very stable, therefore no complex augmentation techniques are required.

# %%
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    # transforms.RandomHorizontalFlip(),
    # transforms.RandomVerticalFlip(),
    transforms.RandomRotation(degrees=5),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

# %% [markdown]
# ### 2.1.2 Create & Split Datasets

# %% [markdown]
# The `DatasetCreator` takes an input folder containing class folders and splits the images into **training** and **validation**.

# %%
dataset_creator = DatasetCreator(source_dir=housing_dataset_input_dir,
                                 output_dir=housing_dataset_output_dir)

# Split datasets
train_dataset, val_dataset = dataset_creator.create_dataset(train_transform=train_transform,
                                                            val_transform=val_transform)
# Out:
# Creating dataset...
# Directory './datasets/housing-classification/train_images' does not exist.
# Split might have been done already.
# Transforming dataset...
#
# Dataset successfully created

# %% [markdown]
# ### 2.1.3 Create Data Loaders

# %%
batch_size = 32

train_loader    = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader      = DataLoader(dataset=val_dataset, batch_size=1)

# %% [markdown]
# ## 2.2 Model Training

# %% [markdown]
# Create CNN instance

# %%
model = ResNet18(n_classes=len(train_dataset.classes), pretrained=True)

# %% [markdown]
# ### 2.2.1 Initialize Hyperparameters

# %%
device          = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
criterion       = nn.CrossEntropyLoss()
n_epochs        = 10
lr              = 0.000001
momentum        = 0.9
lr_scheduler    = True
base_lr         = 0.000001
max_lr          = 0.001
optimizer       = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum)

if lr_scheduler:
    # Create scheduler
    scheduler = torch.optim.lr_scheduler.CyclicLR(
        optimizer,
        base_lr=base_lr,    # Minimum learning rate
        max_lr=max_lr,      # Maximum learning rate
        step_size_up=5,     # Steps to increase LR from base_lr to max_lr
        mode="triangular2"  # Learning rate follows triangular cycle and halves the max_lr each cycle
    )
else:
    scheduler = None

# %% [markdown]
# ### 2.2.2 Train Model

# %% [markdown]
# Create `trainer` object.

# %%
trainer = Trainer(model=model,
                  optimizer=optimizer,
                  criterion=criterion,
                  scheduler=scheduler,
                  device=device)

# %% [markdown]
# Train model.

# %%
loss_list, accuracy_list, best_model = trainer.fit(train_loader=train_loader,
                                                   val_loader=val_loader,
                                                   epochs=n_epochs)
# Out:
#  10%|█         | 1/10 [00:18<02:49, 18.87s/it]
# Epoch 1 done
# Loss: 1.3230 | Val. Accuracy: 0.3333
#  20%|██        | 2/10 [00:37<02:30, 18.79s/it]
# Epoch 2 done
# Loss: 1.1552 | Val. Accuracy: 0.4000
#  30%|███       | 3/10 [00:55<02:08, 18.29s/it]
# Epoch 3 done
# Loss: 1.0334 | Val. Accuracy: 0.5000
#  40%|████      | 4/10 [01:12<01:47, 17.89s/it]
# Epoch 4 done
# Loss: 0.8200 | Val. Accuracy: 0.5667
#  50%|█████     | 5/10 [01:29<01:28, 17.71s/it]
# Epoch 5 done
# Loss: 0.6719 | Val. Accuracy: 0.7333
#  60%|██████    | 6/10 [01:46<01:09, 17.29s/it]
# Epoch 6 done
# Loss: 0.5479 | Val. Accuracy: 0.9333
#  70%|███████   | 7/10 [02:03<00:51, 17.09s/it]
# Epoch 7 done
# Loss: 0.4966 | Val. Accuracy: 0.9333
#  80%|████████  | 8/10 [02:22<00:35, 17.71s/it]
# Epoch 8 done
# Loss: 0.4291 | Val. Accuracy: 0.9333
#  90%|█████████ | 9/10 [02:38<00:17, 17.33s/it]
# Epoch 9 done
# Loss: 0.4085 | Val. Accuracy: 1.0000
# 100%|██████████| 10/10 [02:55<00:00, 17.52s/it]
# Epoch 10 done
# Loss: 0.3900 | Val. Accuracy: 0.9667
#
# Training finished
# Best accuracy: 1.0000

# %% [markdown]
# ### 2.2.3 Plot Results

# %% [markdown]
# As shown in the figure, the highest `validation accuracy` is 100%, it seems to be good to deploy the model.

# %%
plot_results(loss_list, accuracy_list)

# %% [markdown]
# After getting good results, the `model` will be stored

# %%
save_model_as_pt(model, "housing_classifier.pt")
# Out:
# Model saved at ./outputs/models

# %% [markdown]
# # 3. TEST

# %% [markdown]
# After successfully training, the model can be tested on the `test_images` folder corresponding to the `Housing Classification` application.

# %%
# Store file names
image_names = [image_name for image_name in os.listdir(housing_test_images_dir) if image_name.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))]
random.shuffle(image_names)

# Predict
for file_name in image_names:
    full_img_path = os.path.join(housing_test_images_dir, file_name)

    # Make prediction
    x = transform_image(full_img_path, val_transform)
    prediction = model.predict(x)

    # Show image
    _imshow(full_img_path, f"'{file_name}' predicted as {train_dataset.classes[prediction]}")
